# %% [markdown]
# <a href="https://colab.research.google.com/github/mitchhert/notebook/blob/master/Lab_1_IST_210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Do you like Jupyter Notebooks?

# %% [markdown]
# I do like Jupyter Notebooks. I like how it is connected to Google Drive which makes saving my work easier and more efficient.

# %% [markdown]
# # What do you want to learn more about in Jupyter Notebooks?

# %% [markdown]
# I want to learn about the different langauges available through the Jupyter software. I am also interested in how the group share works and the availability of multiple people working on one program.

# %% [markdown]
# ![Beaver.jpg](data:image/jpeg;base64,...)
